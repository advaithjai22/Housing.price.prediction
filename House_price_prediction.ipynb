# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the datasets

# %%
train = pd.read_csv('C:\\Users\\jadva\\OneDrive\\Desktop\\Datasets\\boston\\all\\train.csv')
test = pd.read_csv('C:\\Users\\jadva\\OneDrive\\Desktop\\Datasets\\boston\\all\\test.csv')

# %% [markdown]
# Printing the shape of the dataframe

# %%
print ("Train data shape:", train.shape)
print ("Test data shape:", test.shape)
# Out:
# Train data shape: (1460, 81)
# Test data shape: (1459, 80)

# %% [markdown]
# Inspecting the train dataframe

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Inspecting the skewness of the train dataset

# %%
print ("Skew is:", train.SalePrice.skew())
plt.hist(train.SalePrice, color='blue')
plt.show()
# Out:
# Skew is: 1.8828757597682129

# %% [markdown]
# Using log transformation to reduce the skewness

# %%
target = np.log(train.SalePrice)
print ("Skew is:", target.skew())
plt.hist(target, color='blue')
plt.show()
# Out:
# Skew is: 0.12133506220520406

# %% [markdown]
# Forming a separate dataframe with only the numerical features

# %%
numeric_features = train.select_dtypes(include=[np.number])
numeric_features.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %% [markdown]
# Forming a correlation matix with seaborn

# %%
corrmat = train.corr()
f, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(corrmat, vmax=.8, annot=True);

# %% [markdown]
# Forming a correlation matrix with the features that have the highest correlation

# %%
corrmat = train.corr()
top_corr_features = corrmat.index[abs(corrmat["SalePrice"])>0.5]
plt.figure(figsize=(10,10))
g = sns.heatmap(train[top_corr_features].corr(),annot=True)

# %% [markdown]
# Printing the features that have the highest and lowest correlation with sale price respectively

# %%
corr = numeric_features.corr()

print (corr['SalePrice'].sort_values(ascending=False)[:5], '\n')
print (corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# SalePrice      1.000000
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# Name: SalePrice, dtype: float64
#
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %% [markdown]
# Finding the number of unique values in the OverallQual feature

# %%
train.OverallQual.unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %% [markdown]
# Viewing the distribution of OverallQual with respect to SalePrice

# %%
sns.barplot(train.OverallQual,train.SalePrice)

# %% [markdown]
# Examining the relationship between SalePrice and GrLivArea

# %%
plt.scatter(x=train['GrLivArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Above grade (ground) living area square feet')
plt.show()

# %% [markdown]
# Examining the relationship between SalePrice and GarageArea

# %%
plt.scatter(x=train['GarageArea'], y=target)
plt.ylabel('Sale Price')
plt.xlabel('Garage Area')
plt.show()

# %% [markdown]
# Checking for null values

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:25])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
nulls
# Out:
#               Null Count
# Feature
# PoolQC              1453
# MiscFeature         1406
# Alley               1369
# Fence               1179
# FireplaceQu          690
# LotFrontage          259
# GarageCond            81
# GarageType            81
# GarageYrBlt           81
# GarageFinish          81
# GarageQual            81
# BsmtExposure          38
# BsmtFinType2          38
# BsmtFinType1          37
# BsmtCond              37
# BsmtQual              37
# MasVnrArea             8
# MasVnrType             8
# Electrical             1
# Utilities              0
# YearRemodAdd           0
# MSSubClass             0
# Foundation             0
# ExterCond              0
# ExterQual              0

# %% [markdown]
# Forming a separate dataframe with only the categorical features

# %%
categoricals = train.select_dtypes(exclude=[np.number])
categoricals.describe()
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1      ...      GarageType  \
# count       1460         1460       1460      ...            1379
# unique         3           25          9      ...               6
# top          Gtl        NAmes       Norm      ...          Attchd
# freq        1382          225       1260      ...             870
#
#        GarageFinish GarageQual GarageCond PavedDrive PoolQC  Fence  \
# count          1379       1379       1379       1460      7    281
# unique            3          5          5          3      3      4
# top             Unf         TA         TA          Y     Gd  MnPrv
# ...

# %%
train['enc_street'] = pd.get_dummies(train.Street, drop_first=True)
test['enc_street'] = pd.get_dummies(train.Street, drop_first=True)

# %%
print (train.enc_street.value_counts())
# Out:
# 1    1454
# 0       6
# Name: enc_street, dtype: int64

# %% [markdown]
# Encoding the features

# %%
def encode(x): return 1 if x == 'Partial' else 0
train['enc_condition'] = train.SaleCondition.apply(encode)
test['enc_condition'] = test.SaleCondition.apply(encode)

# %%
condition_pivot = train.pivot_table(index='enc_condition', values='SalePrice', aggfunc=np.median)
condition_pivot.plot(kind='bar', color='blue')
plt.xlabel('Encoded Sale Condition')
plt.ylabel('Median Sale Price')
plt.xticks(rotation=0)
plt.show()

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna()

# %%
sum(data.isnull().sum() != 0)
# Out:
# 0

# %%
y = np.log(train.SalePrice)
X = data.drop(['SalePrice', 'Id'], axis=1)

# %% [markdown]
# Splitting the dataset into test and train set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=.33)

# %% [markdown]
# Fitting the Linear Regression model on the data

# %%
from sklearn import linear_model
lr = linear_model.LinearRegression()

# %%
model = lr.fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %% [markdown]
# Detrmining the RSME values

# %%
from sklearn.metrics import mean_squared_error
print ('RMSE is: \n', mean_squared_error(y_test, predictions))
# Out:
# RMSE is:
#  0.023051468191914157

# %% [markdown]
# Examining the relationship between Actual Price and Predicted Price

# %%
actual_values = y_test
plt.scatter(predictions, actual_values, alpha=.75,
            color='b') #alpha helps to show overlapping data
plt.xlabel('Predicted Price')
plt.ylabel('Actual Price')
plt.title('Linear Regression Model')
plt.show()
